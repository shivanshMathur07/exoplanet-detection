# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_2.csv')

# %%
print(data.shape)
# Out:
# (9564, 141)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Columns: 141 entries, rowid to koi_dikco_msky_err
# dtypes: float64(118), int64(7), object(16)
# memory usage: 10.3+ MB
# None

# %%
#for more clarity renaming the columns that we need
data = data.rename(columns={'kepid':'KepID',
'kepoi_name':'KOIName',
'kepler_name':'KeplerName',
'koi_disposition':'ExoplanetArchiveDisposition',
'koi_pdisposition':'DispositionUsingKeplerData',
'koi_score':'DispositionScore',
'koi_fpflag_nt':'NotTransit-LikeFalsePositiveFlag',
'koi_fpflag_ss':'koi_fpflag_ss',
'koi_fpflag_co':'CentroidOffsetFalsePositiveFlag',
'koi_fpflag_ec':'EphemerisMatchIndicatesContaminationFalsePositiveFlag',
'koi_period':'OrbitalPeriod',
'koi_period_err1':'OrbitalPeriodUpperUnc',
'koi_period_err2':'OrbitalPeriodLowerUnc',
'koi_time0bk':'TransitEpoch',
'koi_time0bk_err1':'TransitEpochUpperUnc',
'koi_time0bk_err2':'TransitEpochLowerUnc',
'koi_impact':'ImpactParamete',
'koi_impact_err1':'ImpactParameterUpperUnc',
'koi_impact_err2':'ImpactParameterLowerUnc',
'koi_duration':'TransitDuration',
'koi_duration_err1':'TransitDurationUpperUnc',
'koi_duration_err2':'TransitDurationLowerUnc',
'koi_depth':'TransitDepth',
'koi_depth_err1':'TransitDepthUpperUnc',
'koi_depth_err2':'TransitDepthLowerUnc',
'koi_prad':'PlanetaryRadius',
'koi_prad_err1':'PlanetaryRadiusUpperUnc',
'koi_prad_err2':'PlanetaryRadiusLowerUnc',
'koi_teq':'EquilibriumTemperature',
'koi_teq_err1':'EquilibriumTemperatureUpperUnc',
'koi_teq_err2':'EquilibriumTemperatureLowerUnc',
'koi_insol':'InsolationFlux',
'koi_insol_err1':'InsolationFluxUpperUnc',
'koi_insol_err2':'InsolationFluxLowerUnc',
'koi_model_snr':'TransitSignal-to-Nois',
'koi_tce_plnt_num':'TCEPlanetNumbe',
'koi_tce_delivname':'TCEDeliver',
'koi_steff':'StellarEffectiveTemperature',
'koi_steff_err1':'StellarEffectiveTemperatureUpperUnc',
'koi_steff_err2':'StellarEffectiveTemperatureLowerUnc',
'koi_slogg':'StellarSurfaceGravity',
'koi_slogg_err1':'StellarSurfaceGravityUpperUnc',
'koi_slogg_err2':'StellarSurfaceGravityLowerUnc',
'koi_srad':'StellarRadius',
'koi_srad_err1':'StellarRadiusUpperUnc',
'koi_srad_err2':'StellarRadiusLowerUnc',
'ra':'RA',
'dec':'Dec',
'koi_kepmag':'Kepler-band'
})

# %%
data.head()
# Out:
#    rowid     KepID    KOIName    KeplerName ExoplanetArchiveDisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b                   CONFIRMED
# 1      2  10797460  K00752.02  Kepler-227 c                   CONFIRMED
# 2      3  10811496  K00753.01           NaN                   CANDIDATE
# 3      4  10848459  K00754.01           NaN              FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b                   CONFIRMED
#
#   koi_vet_stat koi_vet_date DispositionUsingKeplerData  DispositionScore  \
# 0         Done   16-08-2018                  CANDIDATE             1.000
# 1         Done   16-08-2018                  CANDIDATE             0.969
# 2         Done   16-08-2018                  CANDIDATE             0.000
# 3         Done   16-08-2018             FALSE POSITIVE             0.000
# 4         Done   16-08-2018                  CANDIDATE             1.000
#
#    NotTransit-LikeFalsePositiveFlag  ...  koi_dicco_mdec  koi_dicco_mdec_err  \
# 0                                 0  ...           0.200               0.160
# 1                                 0  ...           0.000               0.480
# 2                                 0  ...          -0.034               0.070
# 3                                 0  ...           0.147               0.078
# 4                                 0  ...          -0.090               0.180
#
#    koi_dicco_msky koi_dicco_msky_err koi_dikco_mra  koi_dikco_mra_err  \
# 0           0.200              0.170         0.080              0.130
# 1           0.390              0.360         0.490              0.340
# 2           0.042              0.072         0.002              0.071
# 3           0.289              0.079        -0.257              0.072
# 4           0.100              0.140         0.070              0.180
#
#    koi_dikco_mdec  koi_dikco_mdec_err  koi_dikco_msky  koi_dikco_msky_err
# 0           0.310               0.170           0.320               0.160
# 1           0.120               0.730           0.500               0.450
# 2          -0.027               0.074           0.027               0.074
# 3           0.099               0.077           0.276               0.076
# 4           0.020               0.160           0.070               0.200
#
# [5 rows x 141 columns]

# %%
selected = data
print(selected.shape)
selected = selected.loc[:,selected.columns.intersection(['ExoplanetArchiveDisposition','DispositionUsingKeplerData','OrbitalPeriod','OrbitalPeriodUpperUnc','OrbitalPeriodLowerUnc','TransitEpoch','TransitEpochUpperUnc',
                                                        'TransitEpochLowerUnc','ImpactParamete','ImpactParameterUpperUnc','ImpactParameterLowerUnc',
                                                        'TransitDuration','TransitDurationUpperUnc','TransitDurationLowerUnc','TransitDepth','TransitDepthLowerUnc','TransitDepthUpperUnc',
                                                        'PlanetaryRadius','PlanetaryRadiusUpperUnc','PlanetaryRadiusLowerUnc','EquilibriumTemperature','InsolationFlux','InsolationFluxUpperUnc',
                                                        'InsolationFluxLowerUnc','TransitSignal-to-Nois','TCEPlanetNumbe','StellarEffectiveTemperature','StellarEffectiveTemperatureUpperUnc',
                                                        'StellarEffectiveTemperatureLowerUnc','StellarSurfaceGravity','StellarSurfaceGravityUpperUnc','StellarSurfaceGravityLowerUnc','StellarRadius',
                                                        'StellarRadiusUpperUnc','StellarRadiusLowerUnc','RA','Dec','Kepler-band'])]
print(selected.shape)
selected.head()
# Out:
# (9564, 141)
# (9564, 38)
#   ExoplanetArchiveDisposition DispositionUsingKeplerData  OrbitalPeriod  \
# 0                   CONFIRMED                  CANDIDATE       9.488036
# 1                   CONFIRMED                  CANDIDATE      54.418383
# 2                   CANDIDATE                  CANDIDATE      19.899140
# 3              FALSE POSITIVE             FALSE POSITIVE       1.736952
# 4                   CONFIRMED                  CANDIDATE       2.525592
#
#    OrbitalPeriodUpperUnc  OrbitalPeriodLowerUnc  TransitEpoch  \
# 0           2.780000e-05          -2.780000e-05    170.538750
# 1           2.480000e-04          -2.480000e-04    162.513840
# 2           1.490000e-05          -1.490000e-05    175.850252
# 3           2.630000e-07          -2.630000e-07    170.307565
# 4           3.760000e-06          -3.760000e-06    171.595550
#
#    TransitEpochUpperUnc  TransitEpochLowerUnc  ImpactParamete  \
# 0              0.002160             -0.002160           0.146
# 1              0.003520             -0.003520           0.586
# 2              0.000581             -0.000581           0.969
# 3              0.000115             -0.000115           1.276
# 4              0.001130             -0.001130           0.701
#
#    ImpactParameterUpperUnc  ...  StellarEffectiveTemperatureLowerUnc  \
# 0                    0.318  ...                                -81.0
# 1                    0.059  ...                                -81.0
# 2                    5.126  ...                               -176.0
# 3                    0.115  ...                               -174.0
# 4                    0.235  ...                               -211.0
#
#    StellarSurfaceGravity  StellarSurfaceGravityUpperUnc  \
# 0                  4.467                          0.064
# 1                  4.467                          0.064
# 2                  4.544                          0.044
# 3                  4.564                          0.053
# 4                  4.438                          0.070
#
#    StellarSurfaceGravityLowerUnc  StellarRadius  StellarRadiusUpperUnc  \
# 0                         -0.096          0.927                  0.105
# 1                         -0.096          0.927                  0.105
# 2                         -0.176          0.868                  0.233
# 3                         -0.168          0.791                  0.201
# 4                         -0.210          1.046                  0.334
#
#    StellarRadiusLowerUnc         RA        Dec  Kepler-band
# 0                 -0.061  291.93423  48.141651       15.347
# 1                 -0.061  291.93423  48.141651       15.347
# 2                 -0.078  297.00482  48.134129       15.436
# 3                 -0.067  285.53461  48.285210       15.597
# 4                 -0.133  288.75488  48.226200       15.509
#
# [5 rows x 38 columns]

# %%
#target variables
selected['ExoplanetCandidate'] = selected['DispositionUsingKeplerData'].apply(lambda x: 1 if x == 'CANDIDATE' else 0)
selected['ExoplanetConfirmed'] = selected['ExoplanetArchiveDisposition'].apply(lambda x: 2 if x == 'CONFIRMED' else 1 if x == 'CANDIDATE' else 0 )
#selected.drop(columns=['DispositionUsingKeplerData','ExoplanetArchiveDisposition'],inplace=True)
print(selected.shape)
selected.head()
# Out:
# (9564, 40)
#   ExoplanetArchiveDisposition DispositionUsingKeplerData  OrbitalPeriod  \
# 0                   CONFIRMED                  CANDIDATE       9.488036
# 1                   CONFIRMED                  CANDIDATE      54.418383
# 2                   CANDIDATE                  CANDIDATE      19.899140
# 3              FALSE POSITIVE             FALSE POSITIVE       1.736952
# 4                   CONFIRMED                  CANDIDATE       2.525592
#
#    OrbitalPeriodUpperUnc  OrbitalPeriodLowerUnc  TransitEpoch  \
# 0           2.780000e-05          -2.780000e-05    170.538750
# 1           2.480000e-04          -2.480000e-04    162.513840
# 2           1.490000e-05          -1.490000e-05    175.850252
# 3           2.630000e-07          -2.630000e-07    170.307565
# 4           3.760000e-06          -3.760000e-06    171.595550
#
#    TransitEpochUpperUnc  TransitEpochLowerUnc  ImpactParamete  \
# 0              0.002160             -0.002160           0.146
# 1              0.003520             -0.003520           0.586
# 2              0.000581             -0.000581           0.969
# 3              0.000115             -0.000115           1.276
# 4              0.001130             -0.001130           0.701
#
#    ImpactParameterUpperUnc  ...  StellarSurfaceGravityUpperUnc  \
# 0                    0.318  ...                          0.064
# 1                    0.059  ...                          0.064
# 2                    5.126  ...                          0.044
# 3                    0.115  ...                          0.053
# 4                    0.235  ...                          0.070
#
#    StellarSurfaceGravityLowerUnc  StellarRadius  StellarRadiusUpperUnc  \
# 0                         -0.096          0.927                  0.105
# 1                         -0.096          0.927                  0.105
# 2                         -0.176          0.868                  0.233
# 3                         -0.168          0.791                  0.201
# 4                         -0.210          1.046                  0.334
#
#    StellarRadiusLowerUnc         RA        Dec  Kepler-band  \
# 0                 -0.061  291.93423  48.141651       15.347
# 1                 -0.061  291.93423  48.141651       15.347
# 2                 -0.078  297.00482  48.134129       15.436
# 3                 -0.067  285.53461  48.285210       15.597
# 4                 -0.133  288.75488  48.226200       15.509
#
#    ExoplanetCandidate  ExoplanetConfirmed
# 0                   1                   2
# 1                   1                   2
# 2                   1                   1
# 3                   0                   0
# 4                   1                   2
#
# [5 rows x 40 columns]

# %%
selected.drop(columns=['DispositionUsingKeplerData','ExoplanetArchiveDisposition'],inplace=True)

# %%
#checking for empty values
selected.isna().sum()
selected=selected.dropna(axis=0)
selected.shape
# Out:
# (8744, 38)

# %%
#checking for infinity values
infy_vals = np.isinf(selected).values.sum()
infy_vals
# Out:
# 0

# %%
# import pylab
# import scipy.stats as stats
# measurements=np.random.normal(loc=20,scale=5,size=150)
# stats.probplot(measurements,dist="norm",plot=pylab)
# # pylab.show
# selected1.describe()
# plt.hist(selected1)
# selected1.plot(kind='box')

# %%
##Performing normalization of data
from sklearn.preprocessing import MinMaxScaler
new_data = selected.drop(columns=['ExoplanetCandidate','ExoplanetConfirmed'])
normalized = MinMaxScaler().fit(new_data)
norm_data = normalized.transform(new_data)
norm_data = pd.DataFrame(norm_data)
#have to add back the target variables back to data
norm_data['ExoplanetCandidate'] , norm_data['ExoplanetConfirmed'] = selected['ExoplanetCandidate'] , selected['ExoplanetConfirmed']
norm_data
# Out:
#              0             1         2         3         4         5  \
# 0     0.008617  1.770000e-04  0.999823  0.036999  0.003781  0.996219
# 1     0.050570  1.579548e-03  0.998420  0.031063  0.006171  0.993829
# 2     0.018338  9.483440e-05  0.999905  0.040928  0.001006  0.998994
# 3     0.001379  1.605096e-06  0.999998  0.036828  0.000187  0.999813
# 4     0.002116  2.387898e-05  0.999976  0.037781  0.001971  0.998029
# ...        ...           ...       ...       ...       ...       ...
# 8739  0.000250  6.687899e-07  0.999999  0.008276  0.000283  0.999717
# 8740  0.001382  1.133057e-04  0.999887  0.009235  0.013500  0.986500
# 8741  0.000394  1.540764e-05  0.999985  0.008629  0.004994  0.995006
# 8742  0.311144  2.700630e-02  0.972994  0.024481  0.008895  0.991105
# 8743  0.004292  4.050255e-04  0.999595  0.011448  0.018966  0.981034
#
#              6         7         8         9  ...        28        29  \
# 0     0.001448  0.003718  0.997539  0.020167  ...  0.043478  0.920464
# 1     0.005813  0.000690  0.992532  0.031365  ...  0.043478  0.920464
# 2     0.009613  0.059925  0.998702  0.011673  ...  0.029891  0.854184
# 3     0.012658  0.001344  0.998449  0.016184  ...  0.036005  0.860812
# 4     0.006954  0.002747  0.991942  0.010750  ...  0.047554  0.826015
# ...        ...       ...       ...       ...  ...       ...       ...
# 8739  0.012420  0.000596  0.999174  0.022079  ...  0.023777  0.837614
# 8740  0.000427  0.004945  0.999275  0.021298  ...  0.038043  0.814416
# 8741  0.001458  0.003612  0.997522  0.005044  ...  0.038043  0.814416
# 8742  0.002123  0.002981  0.996392  0.021912  ...  0.020380  0.977630
# 8743  0.001329  0.003776  0.997741  0.021037  ...  0.036685  0.821044
#
#             30        31        32        33        34        35  \
# 0     0.004547  0.003173  0.999412  0.552473  0.733837  0.692702
# 1     0.004547  0.003173  0.999412  0.552473  0.733837  0.692702
# 2     0.004219  0.007041  0.999249  0.784346  0.733360  0.700058
# 3     0.003791  0.006074  0.999355  0.259826  0.742947  0.713365
# 4     0.005208  0.010093  0.998719  0.407085  0.739203  0.706091
# ...        ...       ...       ...       ...       ...       ...
# 8739  0.004413  0.007162  0.999239  0.792756  0.667345  0.588148
# 8740  0.005125  0.010305  0.998902  0.304401  0.671749  0.643938
# 8741  0.005181  0.010305  0.998902  0.654479  0.672578  0.695843
# 8742  0.042884  0.006739  0.981739  0.773282  0.670602  0.333251
# 8743  0.006025  0.012390  0.998680  0.784572  0.669071  0.649640
#
#       ExoplanetCandidate  ExoplanetConfirmed
# 0                    1.0                 2.0
# 1                    1.0                 2.0
# 2                    1.0                 1.0
# 3                    0.0                 0.0
# 4                    1.0                 2.0
# ...                  ...                 ...
# 8739                 0.0                 0.0
# 8740                 0.0                 0.0
# 8741                 0.0                 0.0
# 8742                 0.0                 0.0
# 8743                 0.0                 0.0
#
# [8744 rows x 38 columns]

# %%
##Performing standardization of data
from sklearn.preprocessing import StandardScaler
stand_data = selected.copy()
s_cols = ['OrbitalPeriod','OrbitalPeriodUpperUnc','OrbitalPeriodLowerUnc','TransitEpoch','TransitEpochUpperUnc',
        'TransitEpochLowerUnc','ImpactParamete','ImpactParameterUpperUnc','ImpactParameterLowerUnc',
        'TransitDuration','TransitDurationUpperUnc','TransitDurationLowerUnc','TransitDepth','TransitDepthLowerUnc','TransitDepthUpperUnc',
        'PlanetaryRadius','PlanetaryRadiusUpperUnc','PlanetaryRadiusLowerUnc','EquilibriumTemperature','InsolationFlux','InsolationFluxUpperUnc',
        'InsolationFluxLowerUnc','TransitSignal-to-Nois','TCEPlanetNumbe','StellarEffectiveTemperature','StellarEffectiveTemperatureUpperUnc',
        'StellarEffectiveTemperatureLowerUnc','StellarSurfaceGravity','StellarSurfaceGravityUpperUnc','StellarSurfaceGravityLowerUnc','StellarRadius',
         'StellarRadiusUpperUnc','StellarRadiusLowerUnc','RA','Dec','Kepler-band']
for i in s_cols:
    standard = StandardScaler().fit(stand_data[[i]])
    stand_data[i] = standard.transform(stand_data[[i]])
stand_data
# selected
# Out:
#       OrbitalPeriod  OrbitalPeriodUpperUnc  OrbitalPeriodLowerUnc  \
# 0         -0.396943              -0.248912               0.248912
# 1         -0.014161              -0.218667               0.218667
# 2         -0.308246              -0.250684               0.250684
# 3         -0.462978              -0.252694               0.252694
# 4         -0.456259              -0.252214               0.252214
# ...             ...                    ...                    ...
# 9559      -0.473280              -0.252714               0.252714
# 9560      -0.462953              -0.250285               0.250285
# 9561      -0.471970              -0.252396               0.252396
# 9562       2.363341               0.329648              -0.329648
# 9563      -0.436405              -0.243994               0.243994
#
#       TransitEpoch  TransitEpochUpperUnc  TransitEpochLowerUnc  \
# 0         0.089894             -0.329606              0.329606
# 1        -0.030831             -0.266820              0.266820
# 2         0.169799             -0.402502              0.402502
# 3         0.086416             -0.424015              0.424015
# 4         0.105792             -0.377157              0.377157
# ...            ...                   ...                   ...
# 9559     -0.494311             -0.421476              0.421476
# 9560     -0.474812             -0.074308              0.074308
# 9561     -0.487140             -0.297751              0.297751
# 9562     -0.164703             -0.195263              0.195263
# 9563     -0.429800              0.069269             -0.069269
#
#       ImpactParamete  ImpactParameterUpperUnc  ImpactParameterLowerUnc  \
# 0          -0.180175                -0.174838                 0.150113
# 1          -0.041655                -0.202205                -0.091945
# 2           0.078920                 0.333196                 0.206349
# 3           0.175569                -0.196288                 0.194123
# 4          -0.005451                -0.183608                -0.120471
# ...              ...                      ...                      ...
# 9559        0.168014                -0.203051                 0.229169
# 9560       -0.212602                -0.163744                 0.234059
# 9561       -0.179860                -0.175789                 0.149298
# 9562       -0.158768                -0.181495                 0.094692
# 9563       -0.183953                -0.174310                 0.159893
#
#       TransitDuration  ...  StellarSurfaceGravityUpperUnc  \
# 0           -0.405773  ...                      -0.427193
# 1           -0.160544  ...                      -0.427193
# 2           -0.591781  ...                      -0.577789
# 3           -0.492991  ...                      -0.510021
# 4           -0.611991  ...                      -0.382014
# ...               ...  ...                            ...
# 9559        -0.363897  ...                      -0.645558
# 9560        -0.381005  ...                      -0.487432
# 9561        -0.736940  ...                      -0.487432
# 9562        -0.367553  ...                      -0.683207
# 9563        -0.386703  ...                      -0.502491
#
#       StellarSurfaceGravityLowerUnc  StellarRadius  StellarRadiusUpperUnc  \
# 0                          0.535521      -0.136845              -0.273509
# 1                          0.535521      -0.136845              -0.273509
# 2                         -0.429139      -0.147228              -0.132277
# 3                         -0.332673      -0.160780              -0.167585
# 4                         -0.839120      -0.115902              -0.020837
# ...                             ...            ...                    ...
# 9559                      -0.670304      -0.141069              -0.127864
# 9560                      -1.007935      -0.118542              -0.013113
# 9561                      -1.007935      -0.116782              -0.013113
# 9562                       1.367540       1.076966              -0.143311
# 9563                      -0.911469      -0.090031               0.063020
#
#       StellarRadiusLowerUnc        RA       Dec  Kepler-band  \
# 0                  0.176124 -0.029508  1.198304     0.798724
# 1                  0.176124 -0.029508  1.198304     0.798724
# 2                  0.166736  1.032920  1.196214     0.864972
# 3                  0.172811 -1.370404  1.238186     0.984815
# 4                  0.136364 -0.695669  1.221793     0.919311
# ...                     ...       ...       ...          ...
# 9559               0.166184  1.071458  0.907206    -0.142894
# 9560               0.146856 -1.166165  0.926486     0.359550
# 9561               0.146856  0.437876  0.930114     0.827010
# 9562              -0.837218  0.982227  0.921464    -2.438508
# 9563               0.134155  1.033957  0.914763     0.410911
#
#       ExoplanetCandidate  ExoplanetConfirmed
# 0                      1                   2
# 1                      1                   2
# 2                      1                   1
# 3                      0                   0
# 4                      1                   2
# ...                  ...                 ...
# 9559                   0                   0
# 9560                   1                   1
# 9561                   0                   0
# 9562                   1                   1
# 9563                   0                   0
#
# [8744 rows x 38 columns]

# %%
##Feature & Target Extraction
#for main data
features_main = selected.drop(columns=['ExoplanetCandidate','ExoplanetConfirmed'])
target_main = selected.ExoplanetConfirmed

#for normalised data
features_norm = norm_data.drop(columns=['ExoplanetCandidate','ExoplanetConfirmed'])
target_norm = norm_data.ExoplanetConfirmed

#for standardised data
features_stand = stand_data.drop(columns = ['ExoplanetCandidate','ExoplanetConfirmed'])
target_stand = stand_data.ExoplanetConfirmed

# %%
##splitting training and testing data
from sklearn.model_selection import train_test_split
#for main data
features_main_train , features_main_test , target_main_train , target_main_test = train_test_split(features_main , target_main , test_size=0.3 )
print(features_main_train.shape , features_main_test.shape , target_main_train.shape, target_main_test.shape)

#for normalised data
features_norm_train , features_norm_test , target_norm_train , target_norm_test = train_test_split(features_norm , target_norm , test_size=0.3 )
print(features_norm_train.shape , features_norm_test.shape , target_norm_train.shape, target_norm_test.shape)

#for standardised data
features_stand_train , features_stand_test , target_stand_train , target_stand_test = train_test_split(features_stand , target_stand , test_size=0.3 )
print(features_stand_train.shape , features_stand_test.shape , target_stand_train.shape, target_stand_test.shape)
# Out:
# (6120, 36) (2624, 36) (6120,) (2624,)
# (6120, 36) (2624, 36) (6120,) (2624,)
# (6120, 36) (2624, 36) (6120,) (2624,)

# %%
##model evaluation
##accuracy,precision,recall,f1 score
from sklearn.metrics import accuracy_score , recall_score, precision_score, f1_score, confusion_matrix
def evaluate_score(true,pred):
    print('Accuracy Score is ' + accuracy_score(true , pred))
    print('Accuracy Score is ' + recall_score(true , pred))
    print('Accuracy Score is ' + precision_score(true , pred))
    print('Accuracy Score is ' + f1_score(true , pred))
    print('Accuracy Score is ' + confusion_matrix(true , pred))
